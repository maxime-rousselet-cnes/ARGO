# %%
from xarray import open_dataset
from xarray.core.dataset import Dataset

dataset: Dataset = open_dataset("nodc_D4901820_152.nc")
print(dataset.data_vars)
# Out:
# Data variables:
#     data_type                     object 8B ...
#     format_version                object 8B ...
#     handbook_version              object 8B ...
#     reference_date_time           object 8B ...
#     date_creation                 object 8B ...
#     date_update                   object 8B ...
#     platform_number               (n_prof) object 8B ...
#     project_name                  (n_prof) object 8B ...
#     pi_name                       (n_prof) object 8B ...
#     station_parameters            (n_prof, n_param) object 24B ...
#     cycle_number                  (n_prof) float64 8B ...
#     direction                     (n_prof) object 8B ...
#     data_centre                   (n_prof) object 8B ...
#     dc_reference                  (n_prof) object 8B ...
#     data_state_indicator          (n_prof) object 8B ...
#     data_mode                     (n_prof) object 8B ...
#     platform_type                 (n_prof) object 8B ...
#     float_serial_no               (n_prof) object 8B ...
#     firmware_version              (n_prof) object 8B ...
#     wmo_inst_type                 (n_prof) object 8B ...
#     juld                          (n_prof) datetime64[ns] 8B ...
#     juld_qc                       (n_prof) object 8B ...
#     juld_location                 (n_prof) datetime64[ns] 8B ...
#     latitude                      (n_prof) float64 8B ...
#     longitude                     (n_prof) float64 8B ...
#     position_qc                   (n_prof) object 8B ...
#     positioning_system            (n_prof) object 8B ...
#     profile_pres_qc               (n_prof) object 8B ...
#     profile_temp_qc               (n_prof) object 8B ...
#     profile_psal_qc               (n_prof) object 8B ...
#     vertical_sampling_scheme      (n_prof) object 8B ...
#     config_mission_number         (n_prof) float64 8B ...
#     pres                          (n_prof, n_levels) float32 2kB ...
#     pres_qc                       (n_prof, n_levels) object 5kB ...
#     pres_adjusted                 (n_prof, n_levels) float32 2kB ...
#     pres_adjusted_qc              (n_prof, n_levels) object 5kB ...
#     pres_adjusted_error           (n_prof, n_levels) float32 2kB ...
#     temp                          (n_prof, n_levels) float32 2kB ...
#     temp_qc                       (n_prof, n_levels) object 5kB ...
#     temp_adjusted                 (n_prof, n_levels) float32 2kB ...
#     temp_adjusted_qc              (n_prof, n_levels) object 5kB ...
#     temp_adjusted_error           (n_prof, n_levels) float32 2kB ...
#     psal                          (n_prof, n_levels) float32 2kB ...
#     psal_qc                       (n_prof, n_levels) object 5kB ...
#     psal_adjusted                 (n_prof, n_levels) float32 2kB ...
#     psal_adjusted_qc              (n_prof, n_levels) object 5kB ...
#     psal_adjusted_error           (n_prof, n_levels) float32 2kB ...
#     parameter                     (n_prof, n_calib, n_param) object 24B ...
#     scientific_calib_equation     (n_prof, n_calib, n_param) object 24B ...
#     scientific_calib_coefficient  (n_prof, n_calib, n_param) object 24B ...
#     scientific_calib_comment      (n_prof, n_calib, n_param) object 24B ...
#     scientific_calib_date         (n_prof, n_calib, n_param) object 24B ...
#     history_institution           (n_history, n_prof) object 72B ...
#     history_step                  (n_history, n_prof) object 72B ...
#     history_software              (n_history, n_prof) object 72B ...
#     history_software_release      (n_history, n_prof) object 72B ...
#     history_reference             (n_history, n_prof) object 72B ...
#     history_date                  (n_history, n_prof) object 72B ...
#     history_action                (n_history, n_prof) object 72B ...
#     history_parameter             (n_history, n_prof) object 72B ...
#     history_start_pres            (n_history, n_prof) float32 36B ...
#     history_stop_pres             (n_history, n_prof) float32 36B ...
#     history_previous_value        (n_history, n_prof) float32 36B ...
#     history_qctest                (n_history, n_prof) object 72B ...
#     crs                           int32 4B ...

# %%
dataset["psal"]
# Out:
# <xarray.DataArray 'psal' (n_prof: 1, n_levels: 564)> Size: 2kB
# [564 values with dtype=float32]
# Dimensions without coordinates: n_prof, n_levels
# Attributes:
#     long_name:       Practical salinity
#     standard_name:   sea_water_salinity
#     units:           psu
#     valid_min:       2.0
#     valid_max:       41.0
#     C_format:        %9.3f
#     FORTRAN_format:  F9.3
#     resolution:      0.001

# %%
from matplotlib.pyplot import plot
from gsw import z_from_p

plot(dataset["temp_adjusted"].values[0], z_from_p(p=dataset["pres"].values[0], lat=dataset["latitude"].values[0]))
